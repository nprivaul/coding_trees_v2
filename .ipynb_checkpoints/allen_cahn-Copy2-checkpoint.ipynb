# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/nguwijy/coding_trees/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # suppress INFO and WARNING
import gc
# install the package if not yet installed
#try:
#    from branch.branch import Net
#except:
#    !python -m pip install git+https://github.com/nguwijy/deep_branching_with_domain.git
#    from branch.branch import Net
import math
import time

import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("torch.cuda.is_available=",torch.cuda.is_available())
if torch.cuda.device_count() > 1:
    device0 = torch.device("cuda:0")
    device1 = torch.device("cuda:1")
else:
    device0 = device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.set_default_dtype(torch.float64)

from DeepBSDE2.main import main as deep_bsde

from branch.branch_v2 import Net
from branch.branch_NPP23 import Net_NPP23

# from branch.branch_cv import Net_cv
# Out:
# torch.cuda.is_available= True
# 2026-03-01 10:43:56.404898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772333036.420187 1666744 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772333036.424456 1666744 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772333036.437887 1666744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772333036.437905 1666744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772333036.437906 1666744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772333036.437907 1666744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow is using: NVIDIA RTX A4000 (GPU 0)

# %% [markdown]
# ## Allen Cahn Equation

# %%
def blow_up_analysis(T_arr, 
                     fixed_dim,
                     dim, 
                     branch_nb_path_per_state, 
                     branch_nb_states_per_batch, 
                     branch_nb_states,
                     outlier_percentile,
                     repeats,
                     num_iterations,
                     y_init_range,
                     nu, 
                     xlo, 
                     xhi):

    problem_name = f"allen_cahn_dim_{dim}_time_behavior"

    deriv_map = np.array([0] * dim).reshape(-1, dim)

    mu=1
    def f_example2(y):
        """
        idx 0 -> no deriv
        """
        return mu * ( y - y ** 3 ) 

    def f_example(y):
        """
        idx 0 -> no deriv
        """
        return mu * ( y[0] - y[0] ** 3 )

    def f_example_NPP23(y, coordinate=0):
        """
        idx 0 -> no deriv
        """
        return mu * ( y[0] - y[0] ** 3 )

    def phi_example(x, coordinate=0):
        scale = torch.sqrt(torch.tensor(x.shape[0], dtype=x.dtype, device=x.device))
        z = x.sum(dim=0) / scale
        z = -0.5 * z
        return -0.5 - 0.5 * torch.tanh(z)

    def phi_example_NPP23(x, coordinate=0):
        return (-0.5 - 0.5 * torch.nn.Tanh()(-.5 * x.sum(dim=0) / math.sqrt(dim)))

    def exact_example(t, x, T, coordinate=0):
        t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
        x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
        T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
        return -0.5 - 0.5 * torch.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

    def exact_example_NPP23(t, x, T, coordinate=0):
        t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
        x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
        T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
        return -0.5 - 0.5 * torch.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

    df = []
    for T in T_arr:
#        print(f"Now dealing with T = {T}...")
        # initialize branching model
        torch.manual_seed(0)
        model = Net(
            problem_name=problem_name,
            f_fun2=f_example2,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            device=device1,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
             save_as_tmp=True,
        ).to(device1)

        model_NPP23 = Net_NPP23(
            problem_name=problem_name,
            f_fun=f_example_NPP23,
#            f_fun_NPP23=f_example_NPP23,
            exact_fun_NPP23=exact_example_NPP23,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            phi_fun_NPP23=phi_example_NPP23,
            device=device0,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
            save_as_tmp=True,
        ).to(device0)
        
        tx = torch.zeros(1, dim + 1, device=device1)
        tx[:, -1] = torch.linspace(model.x_lo, model.x_hi, 1)
        
        # branching mc calculation
        start = time.time()
        mc = 0
        for _ in range(repeats):
            x, y = model.gen_sample(patch=0, tx=tx)
            mc += y[:, 0].cpu()
        mc = mc[0].item() / repeats
        mc_time = time.time() - start

        tx=tx.to(device0)
        start = time.time()
        mc_NPP23 = 0
        for _ in range(repeats):
            x, y = model_NPP23.gen_sample(patch=0, tx=tx)
            mc_NPP23 += y[:, 0].cpu()
        mc_NPP23 = mc_NPP23[0].item() / repeats
        mc_NPP23_time = time.time() - start
        
        xz = tx[:, 1:].T.unsqueeze(-1).repeat((1, 1, 1))
        exact = exact_example(t=0, x=xz.cpu(), T=T, coordinate=0)[0].cpu().item()
        start = time.time()
        bsde = deep_bsde(total_time=T, verbose=False, nu=nu, dim=dim, num_iterations=num_iterations, y_init_range=y_init_range)[-1][2]
        bsde_time = time.time() - start
        # exact = 0.61061
        df.append([format(T, ".2f"), format(mc, ".5f"), format(mc_NPP23,".5f"), format(bsde,".5f"), format(exact,".5f"), format(mc_time,".2f"), format(mc_NPP23_time,".2f"), format(bsde_time,".2f")])
        print(problem_name)
        print("dim=",dim)
        print(pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time']))

        del model              # remove model object
        del model_NPP23
        gc.collect()           # free Python objects
        torch.cuda.empty_cache()  # release cached GPU memory
    
    # create df & save
    if not os.path.isdir('logs/'):
        os.makedirs('logs/')
    df = pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time'])
    df.to_csv("logs/" + problem_name + ".csv")

    grid_1d = np.linspace(0,T,100) 
    x_mid = (xlo + xhi) / 2
    exact = exact_example(0, x_mid * np.ones((fixed_dim, 100)), grid_1d)

    fig, ax = plt.subplots()
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='-', color='red', label='Binary')
    ax.plot(df['T'].astype(float), df['NPP23'].astype(float), color='blue', label='NPP23')
    ax.plot(df['T'].astype(float), df['exact'].astype(float), color='black', label='Exact',linestyle='--')
    ax.plot(df['T'].astype(float), df['bsde'].astype(float), color='purple', label='BSDE')
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='None', marker='o', color='red', markerfacecolor='none')
    ax.set_xlabel("T")
    ax.margins(x=0)
    ax.legend(loc="upper right")
    plt.tight_layout()
    ax.grid(True)
    fig.savefig("logs/" + problem_name + ".pdf", bbox_inches="tight")
    # Save df to LaTeX
    df = df.astype(str)
    latex_str = df.to_latex(
        index=False,             
    #    float_format="%.5f",      
        column_format="c"*len(df.columns),  
        caption=None,             
        label=None,               
        bold_rows=False
    )
    with open("logs/" + problem_name + "table.tex", "w") as f:
        f.write(latex_str)    
        
    return df

# %%
T=0.5
delta_t = 0.05
T_arr = np.arange(delta_t, T + delta_t, delta_t)
branch_nb_path_per_state=10000
branch_nb_states_per_batch=10
branch_nb_states=1000
outlier_percentile=5
repeats=100
num_iterations=4000
y_init_range=[-1,0]
xlo=0.0
xhi=0.0
nu=1.0

# %% [markdown]
# ### Dimension d = 1

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
# Out:
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# I0000 00:00:1772333042.381449 1666744 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12644 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:21:00.0, compute capability: 8.6
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# 3  0.20  -0.57327  -0.57425  -0.57463  -0.57444    1.87     2.02    239.77
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# 3  0.20  -0.57327  -0.57425  -0.57463  -0.57444    1.87     2.02    239.77
# 4  0.25  -0.58971  -0.59302  -0.59280  -0.59267    1.65     1.86    237.87
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# 3  0.20  -0.57327  -0.57425  -0.57463  -0.57444    1.87     2.02    239.77
# 4  0.25  -0.58971  -0.59302  -0.59280  -0.59267    1.65     1.86    237.87
# 5  0.30  -0.60548  -0.61023  -0.61102  -0.61064    2.14     2.07    235.03
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# 3  0.20  -0.57327  -0.57425  -0.57463  -0.57444    1.87     2.02    239.77
# 4  0.25  -0.58971  -0.59302  -0.59280  -0.59267    1.65     1.86    237.87
# 5  0.30  -0.60548  -0.61023  -0.61102  -0.61064    2.14     2.07    235.03
# 6  0.35  -0.63331  -0.62881  -0.62860  -0.62832    1.96     2.28    234.97
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51878  -0.51875  -0.51875  -0.51874    2.07     1.94    242.25
# 1  0.10  -0.53627  -0.53740  -0.53749  -0.53743    2.03     2.16    239.14
# 2  0.15  -0.55253  -0.55580  -0.55608  -0.55601    1.76     2.12    232.32
# 3  0.20  -0.57327  -0.57425  -0.57463  -0.57444    1.87     2.02    239.77
# 4  0.25  -0.58971  -0.59302  -0.59280  -0.59267    1.65     1.86    237.87
# 5  0.30  -0.60548  -0.61023  -0.61102  -0.61064    2.14     2.07    235.03
# 6  0.35  -0.63331  -0.62881  -0.62860  -0.62832    1.96     2.28    234.97
# 7  0.40  -0.66164  -0.64666  -0.64592  -0.64566    1.60     2.24    233.60
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = blow_up_analysis(
#       2     T_arr=T_arr,
#       3     fixed_dim=0,
#       4     dim=1,
#       5     branch_nb_path_per_state=branch_nb_path_per_state,
#       6     branch_nb_states_per_batch=branch_nb_states_per_batch,
#       7     branch_nb_states=branch_nb_states,
#       8     outlier_percentile=outlier_percentile,
#       9     repeats=repeats,
#      10     nu=nu,
#      11     num_iterations=num_iterations,
#      12     y_init_range=y_init_range,
#      13     xlo=xlo,
#      14     xhi=xhi
#      15 )
#
# Cell In[2], line 127, in blow_up_analysis(T_arr, fixed_dim, dim, branch_nb_path_per_state, branch_nb_states_per_batch, branch_nb_states, outlier_percentile, repeats, num_iterations, y_init_range, nu, xlo, xhi)
#     125 exact = exact_example(t=0, x=xz.cpu(), T=T, coordinate=0)[0].cpu().item()
#     126 start = time.time()
# --> 127 bsde = deep_bsde(total_time=T, verbose=False, nu=nu, dim=dim, num_iterations=num_iterations, y_init_range=y_init_range)[-1][2]
#     128 bsde_time = time.time() - start
#     129 # exact = 0.61061
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/main.py:93, in main(total_time, dim, nu, num_time_interval, y_init_range, num_hiddens, lr_values, lr_boundaries, num_iterations, batch_size, valid_size, logging_frequency, dtype, verbose)
#      91 logging.info('Begin to solve %s ' % eqn_config.eqn_name)
#      92 bsde_solver = BSDESolver(config, bsde)
# ---> 93 training_history = bsde_solver.train()
#      94 if bsde.y_init:
#      95     logging.info('Y0_true: %.4e' % bsde.y_init)
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/solver.py:37, in BSDESolver.train(self)
#      34         if self.net_config.verbose:
#      35             logging.info("step: %5u,    loss: %.4e, Y0: %.4e,   elapsed time: %3u" % (
#      36                 step, loss, y_init, elapsed_time))
# ---> 37     self.train_step(self.bsde.sample(self.net_config.batch_size))
#      38 return np.array(training_history)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:869, in Function._call(self, *args, **kwds)
#     866   self._lock.release()
#     867   # In this case we have created variables on the first call, so we run the
#     868   # defunned version which is guaranteed to never create variables.
# --> 869   return tracing_compilation.call_function(
#     870       args, kwds, self._no_variable_creation_config
#     871   )
#     872 elif self._variable_creation_config is not None:
#     873   # Release the lock early so that multiple threads can perform the call
#     874   # in parallel.
#     875   self._lock.release()
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Dimension d = 10

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=10,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 100

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=100,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %%
print(torch.cuda.is_available())

# %% [markdown]
# ### Dimension d = 300

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=300,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 500

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=500,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 1000

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1000,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
