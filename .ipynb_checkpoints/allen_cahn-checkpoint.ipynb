# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/nguwijy/coding_trees/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # suppress INFO and WARNING
import gc
# install the package if not yet installed
#try:
#    from branch.branch import Net
#except:
#    !python -m pip install git+https://github.com/nguwijy/deep_branching_with_domain.git
#    from branch.branch import Net
import math
import time

import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("torch.cuda.is_available=",torch.cuda.is_available())
if torch.cuda.device_count() > 1:
    device0 = torch.device("cuda:0")
    device1 = torch.device("cuda:1")
else:
    device0 = device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.set_default_dtype(torch.float64)

from DeepBSDE2.main import main as deep_bsde

from branch.branch_v2 import Net
from branch.branch_NPP23 import Net_NPP23

# from branch.branch_cv import Net_cv
# Out:
# torch.cuda.is_available= True
# 2026-03-02 10:55:46.429379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772420146.443122 1801265 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772420146.447374 1801265 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772420146.458720 1801265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772420146.458739 1801265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772420146.458740 1801265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772420146.458741 1801265 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow is using: NVIDIA RTX A4000 (GPU 0)

# %% [markdown]
# ## Allen Cahn Equation

# %%
def blow_up_analysis(T_arr, 
                     fixed_dim,
                     dim, 
                     branch_nb_path_per_state, 
                     branch_nb_states_per_batch, 
                     branch_nb_states,
                     branch_exponential_lambda,
                     outlier_percentile,
                     repeats,
                     num_iterations,
                     y_init_range,
                     nu, 
                     xlo, 
                     xhi):

    problem_name = f"allen_cahn_dim_{dim}_time_behavior"

    deriv_map = np.array([0] * dim).reshape(-1, dim)

    mu=1

    def f_example(y, coordinate=0):
        """
        idx 0 -> no deriv
        """
        return mu * ( y[0] - y[0] ** 3 )

    def phi_example(x, coordinate=0):
        scale = torch.sqrt(torch.tensor(x.shape[0], dtype=x.dtype, device=x.device))
        z = x.sum(dim=0) / scale
        z = -0.5 * z
        return -0.5 - 0.5 * torch.tanh(z)

    def exact_example(t, x, T, coordinate=0):
        t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
        x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
        T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
        return -0.5 - 0.5 * torch.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

    df = []
    for T in T_arr:
#        print(f"Now dealing with T = {T}...")
        # initialize branching model
        torch.manual_seed(0)
        model = Net(
            branch_exponential_lambda=branch_exponential_lambda,
            problem_name=problem_name,
            f_fun2=f_example,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            device=device1,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            epochs=1,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
             save_as_tmp=True,
        ).to(device1)

        model_NPP23 = Net_NPP23(
            branch_exponential_lambda=branch_exponential_lambda,
            problem_name=problem_name,
            f_fun=f_example,
            exact_fun_NPP23=exact_example,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            phi_fun_NPP23=phi_example,
            device=device0,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            epochs=1,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
            save_as_tmp=True,
        ).to(device0)
        
        tx = torch.zeros(1, dim + 1, device=device1)
        tx[:, -1] = torch.linspace(model.x_lo, model.x_hi, 1)
        
        # branching mc calculation
        start = time.time()
        mc = 0
        for _ in range(repeats):
            x, y = model.gen_sample(patch=0, tx=tx)
            mc += y[:, 0].cpu()
        mc = mc[0].item() / repeats
        mc_time = time.time() - start

        tx=tx.to(device0)
        start = time.time()
        mc_NPP23 = 0
        for _ in range(repeats):
            x, y = model_NPP23.gen_sample(patch=0, tx=tx)
            mc_NPP23 += y[:, 0].cpu()
        mc_NPP23 = mc_NPP23[0].item() / repeats
        mc_NPP23_time = time.time() - start
        
        xz = tx[:, 1:].T.unsqueeze(-1).repeat((1, 1, 1))
        exact = exact_example(t=0, x=xz.cpu(), T=T, coordinate=0)[0].cpu().item()
        start = time.time()
        bsde = deep_bsde(total_time=T, verbose=False, nu=nu, dim=dim, num_iterations=num_iterations, y_init_range=y_init_range)[-1][2]
        bsde_time = time.time() - start
        # exact = 0.61061
        df.append([format(T, ".2f"), format(mc, ".5f"), format(mc_NPP23,".5f"), format(bsde,".5f"), format(exact,".5f"), format(mc_time,".2f"), format(mc_NPP23_time,".2f"), format(bsde_time,".2f")])
        print(problem_name)
        print("dim=",dim)
        print(pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time']))

        del model              # remove model object
        del model_NPP23
        gc.collect()           # free Python objects
        torch.cuda.empty_cache()  # release cached GPU memory
    
    # create df & save
    if not os.path.isdir('logs/'):
        os.makedirs('logs/')
    df = pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time'])
    df.to_csv("logs/" + problem_name + ".csv")

    grid_1d = np.linspace(0,T,100) 
    x_mid = (xlo + xhi) / 2
    exact = exact_example(0, x_mid * np.ones((fixed_dim, 100)), grid_1d)

    fig, ax = plt.subplots()
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='-', color='red', label='Binary')
    ax.plot(df['T'].astype(float), df['NPP23'].astype(float), color='blue', label='NPP23')
    ax.plot(df['T'].astype(float), df['exact'].astype(float), color='black', label='Exact',linestyle='--')
    ax.plot(df['T'].astype(float), df['bsde'].astype(float), color='purple', label='BSDE')
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='None', marker='o', color='red', markerfacecolor='none')
    ax.set_xlabel("T")
    ax.margins(x=0)
    ax.legend(loc="upper right")
    plt.tight_layout()
    ax.grid(True)
    fig.savefig("logs/" + problem_name + ".pdf", bbox_inches="tight")
    # Save df to LaTeX
    df = df.astype(str)
    latex_str = df.to_latex(
        index=False,             
    #    float_format="%.5f",      
        column_format="c"*len(df.columns),  
        caption=None,             
        label=None,               
        bold_rows=False
    )
    with open("logs/" + problem_name + "table.tex", "w") as f:
        f.write(latex_str)    
        
    return df

# %% [markdown]
# ### Dimension d = 1

# %%
T=0.5
delta_t = 0.05
T_arr = np.arange(delta_t, T + delta_t, delta_t)
branch_nb_path_per_state=20000
branch_nb_states_per_batch=10
branch_nb_states=10
branch_exponential_lambda=- 4 * math.log(.95)/T
outlier_percentile=5
repeats=2000
num_iterations=4000
y_init_range=[-1,0]
xlo=0.0
xhi=0.0
nu=1.0

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    branch_exponential_lambda=branch_exponential_lambda,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
# Out:
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# I0000 00:00:1772420152.402015 1801265 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12612 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:21:00.0, compute capability: 8.6
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51926  -0.51868  -0.51879  -0.51874    2.05     2.03    232.85
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51926  -0.51868  -0.51879  -0.51874    2.05     2.03    232.85
# 1  0.10  -0.53772  -0.53749  -0.53749  -0.53743    1.59     1.96    229.80
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Begin to solve Allen-Cahn3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = blow_up_analysis(
#       2     T_arr=T_arr,
#       3     fixed_dim=0,
#       4     dim=1,
#       5     branch_nb_path_per_state=branch_nb_path_per_state,
#       6     branch_nb_states_per_batch=branch_nb_states_per_batch,
#       7     branch_nb_states=branch_nb_states,
#       8     outlier_percentile=outlier_percentile,
#       9     repeats=repeats,
#      10     nu=nu,
#      11     num_iterations=num_iterations,
#      12     y_init_range=y_init_range,
#      13     xlo=xlo,
#      14     xhi=xhi
#      15 )
#
# Cell In[2], line 108, in blow_up_analysis(T_arr, fixed_dim, dim, branch_nb_path_per_state, branch_nb_states_per_batch, branch_nb_states, outlier_percentile, repeats, num_iterations, y_init_range, nu, xlo, xhi)
#     106 exact = exact_example(t=0, x=xz.cpu(), T=T, coordinate=0)[0].cpu().item()
#     107 start = time.time()
# --> 108 bsde = deep_bsde(total_time=T, verbose=False, nu=nu, dim=dim, num_iterations=num_iterations, y_init_range=y_init_range)[-1][2]
#     109 bsde_time = time.time() - start
#     110 # exact = 0.61061
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/main.py:93, in main(total_time, dim, nu, num_time_interval, y_init_range, num_hiddens, lr_values, lr_boundaries, num_iterations, batch_size, valid_size, logging_frequency, dtype, verbose)
#      91 logging.info('Begin to solve %s ' % eqn_config.eqn_name)
#      92 bsde_solver = BSDESolver(config, bsde)
# ---> 93 training_history = bsde_solver.train()
#      94 if bsde.y_init:
#      95     logging.info('Y0_true: %.4e' % bsde.y_init)
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/solver.py:30, in BSDESolver.train(self)
#      28 for step in range(self.net_config.num_iterations+1):
#      29     if step % self.net_config.logging_frequency == 0:
# ---> 30         loss = self.loss_fn(valid_data, training=False).numpy()
#      31         y_init = self.y_init.numpy()[0]
#      32         elapsed_time = time.time() - start_time
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/solver.py:42, in BSDESolver.loss_fn(self, inputs, training)
#      40 def loss_fn(self, inputs, training):
#      41     dw, x = inputs
# ---> 42     y_terminal = self.model(inputs, training=training)
#      43     delta = y_terminal - self.bsde.g_tf(self.bsde.total_time, x[:, :, -1])
#      44     # use linear approximation outside the clipped range
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/layers/layer.py:826, in Layer.__call__(self, *args, **kwargs)
#     823 ################
#     824 # 4. Call build
#     825 with self._open_name_scope():
# --> 826     self._maybe_build(call_spec)
#     828 ##########################
#     829 # 5. Infer training value
#     830 # Training phase for `Layer.call` is set via (in order of priority):
#    (...)
#     836 # Maintains info about the `Layer.call` stack
#     837 # across nested calls.
#     838 call_context = self._get_call_context()
#
# File ~/.local/lib/python3.12/site-packages/keras/src/layers/layer.py:1376, in Layer._maybe_build(self, call_spec)
#    1374 if might_have_unbuilt_state(self):
#    1375     try:
# -> 1376         backend.compute_output_spec(
#    1377             self.call, **call_spec.arguments_dict
#    1378         )
#    1379     except Exception as e:
#    1380         if call_spec.eager:
#    1381             # Will let the actual eager call do state-building
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:212, in compute_output_spec(fn, *args, **kwargs)
#     207     return x
#     209 args, kwargs = tree.map_structure(
#     210     convert_keras_tensor_to_tf, (args, kwargs)
#     211 )
# --> 212 tf_out = fn(*args, **kwargs)
#     214 def convert_tf_to_keras_tensor(x):
#     215     if tf.is_tensor(x):
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/solver.py:106, in NonsharedModel.call(self, inputs, training)
#     102 for t in range(0, self.bsde.num_time_interval-1):
#     103     y = y - self.bsde.delta_t * (
#     104         self.bsde.f_tf(time_stamp[t], x[:, :, t], y, z)
#     105     ) + tf.reduce_sum(z * dw[:, :, t], 1, keepdims=True)
# --> 106     z = self.subnet[t](x[:, :, t + 1], training=training) / self.bsde.dim
#     107 # terminal time
#     108 y = y - self.bsde.delta_t * self.bsde.f_tf(time_stamp[-1], x[:, :, -2], y, z) + \
#     109     tf.reduce_sum(z * dw[:, :, -1], 1, keepdims=True)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/DeepBSDE2/solver.py:142, in FeedForwardSubNet.call(self, x, training)
#     140     x = tf.nn.relu(x)
#     141 x = self.dense_layers[-1](x)
# --> 142 x = self.bn_layers[-1](x, training=training)
#     143 return x
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/.local/lib/python3.12/site-packages/keras/src/layers/normalization/batch_normalization.py:259, in BatchNormalization.call(self, inputs, training, mask)
#     256     variance = moving_variance
#     258 if self.scale:
# --> 259     gamma = ops.cast(self.gamma, inputs.dtype)
#     260 else:
#     261     gamma = None
#
# File ~/.local/lib/python3.12/site-packages/keras/src/ops/core.py:800, in cast(x, dtype)
#     798 if any_symbolic_tensors((x,)):
#     799     return Cast(dtype=dtype)(x)
# --> 800 return backend.core.cast(x, dtype)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:189, in cast(x, dtype)
#     187     return x
#     188 else:
# --> 189     return tf.cast(x, dtype=dtype)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/math_ops.py:1012, in cast(x, dtype, name)
#    1006   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1007 else:
#    1008   # TODO(josh11b): If x is not already a Tensor, we could return
#    1009   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1010   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1011   # strings.
# -> 1012   x = ops.convert_to_tensor(x, name="x")
#    1013   if x.dtype.is_complex and base_type.is_floating:
#    1014     logging.warn(
#    1015         f"You are casting an input of type {x.dtype.name} to an "
#    1016         f"incompatible dtype {base_type.name}.  This will "
#    1017         "discard the imaginary part and may not be what you "
#    1018         "intended."
#    1019     )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:736, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     734 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     735 preferred_dtype = preferred_dtype or dtype_hint
# --> 736 return tensor_conversion_registry.convert(
#     737     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     738 )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:77, in Variable.__tf_tensor__(self, dtype, name)
#      76 def __tf_tensor__(self, dtype=None, name=None):
# ---> 77     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/common/variables.py:219, in KerasVariable.value(self)
#     212         return self._maybe_autocast(value)
#     213 if self._value is None:
#     214     # Uninitialized variable. Return a placeholder.
#     215     # This is fine because it's only ever used
#     216     # in during shape inference / graph tracing
#     217     # (anything else would be a bug, to be fixed.)
#     218     return self._maybe_autocast(
# --> 219         self._initializer(self._shape, dtype=self._dtype)
#     220     )
#     221 return self._maybe_autocast(self._value)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/init_ops_v2.py:360, in RandomUniform.__call__(self, shape, dtype, **kwargs)
#     358 if _PARTITION_SHAPE in kwargs:
#     359   shape = kwargs[_PARTITION_SHAPE]
# --> 360 return self._random_generator.random_uniform(shape, self.minval,
#     361                                              self.maxval, dtype)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/init_ops_v2.py:1095, in _RandomGenerator.random_uniform(self, shape, minval, maxval, dtype)
#    1093 else:
#    1094   op = random_ops.random_uniform
# -> 1095 return op(
#    1096     shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/random_ops.py:295, in random_uniform(shape, minval, maxval, dtype, seed, name)
#     293   maxval = 1
#     294 with ops.name_scope(name, "random_uniform", [shape, minval, maxval]) as name:
# --> 295   shape = shape_util.shape_tensor(shape)
#     296   # In case of [0,1) floating results, minval and maxval is unused. We do an
#     297   # `is` comparison here since this is cheaper than isinstance or  __eq__.
#     298   minval_is_zero = isinstance(minval, int) and minval == 0
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/shape_util.py:35, in shape_tensor(shape)
#      29   else:
#      30     # If there are Dimension objects in the shape, unwrap them. This can be a
#      31     # problem if v1 and v2 TensorShape objects get mixed up in partial
#      32     # conversions, leading to shapes such as (1, 2, Dimension(5)), which are
#      33     # not convertible to Tensors because of mixed content.
#      34     shape = tuple(map(tensor_shape.dimension_value, shape))
# ---> 35 return ops.convert_to_tensor(shape, dtype=dtype, name="shape")
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:736, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     734 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     735 preferred_dtype = preferred_dtype or dtype_hint
# --> 736 return tensor_conversion_registry.convert(
#     737     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     738 )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py:1327, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1325 def _autopacking_conversion_function(v, dtype=None, name=None, as_ref=False):
#    1326   """Tensor conversion function that automatically packs arguments."""
# -> 1327   if as_ref or _should_not_autopack(v):
#    1328     return NotImplemented
#    1329   inferred_dtype = _get_dtype_from_nested_lists(v)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py:1321, in _should_not_autopack(v)
#    1315 def _should_not_autopack(v):
#    1316   # The condition we really want is
#    1317   #    any(isinstance(elem, core.Tensor))
#    1318   # but it is >5x slower due to abc.ABCMeta.__instancecheck__.
#    1319   # pylint: disable=unidiomatic-typecheck
#    1320   # TODO(slebedev): add nest.all?
# -> 1321   return all(type(elem) in _NON_AUTOPACKABLE_TYPES for elem in nest.flatten(v))
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/nest.py:293, in flatten(structure, expand_composites)
#     198 @tf_export("nest.flatten")
#     199 def flatten(structure, expand_composites=False):
#     200   """Returns a flat list from a given structure.
#     201
#     202   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     291     TypeError: The nest is or contains a dict with non-sortable keys.
#     292   """
# --> 293   return nest_util.flatten(
#     294       nest_util.Modality.CORE, structure, expand_composites
#     295   )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/nest_util.py:615, in flatten(modality, structure, expand_composites)
#     611       index += 1
#     612   return index, packed
# --> 615 def flatten(modality, structure, expand_composites=False):
#     616   """Flattens a nested structure.
#     617
#     618   - For Modality.CORE: refer to
#    (...)
#     709     TypeError: The nest is or contains a dict with non-sortable keys.
#     710   """
#     711   if modality == Modality.CORE:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Dimension d = 10

# %%
repeats=500

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=10,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    branch_exponential_lambda=branch_exponential_lambda,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 100

# %%
repeats=100

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=100,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    branch_exponential_lambda=branch_exponential_lambda,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 1000

# %%
repeats=6

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1000,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    branch_exponential_lambda=branch_exponential_lambda,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
