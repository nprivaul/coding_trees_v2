# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/nguwijy/coding_trees/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
#import subprocess
#import sys
#import site
#
## Get Python info
#print(f"Python executable: {sys.executable}")
#print(f"Python path: {sys.path}")
#
## Force reinstall rich
#subprocess.check_call([sys.executable, "-m", "pip", "uninstall", "rich", "-y"])
#subprocess.check_call([sys.executable, "-m", "pip", "install", "rich", "--no-cache-dir"])
#
## Check where packages are installed
#print("Site packages locations:")
#for path in site.getsitepackages():
#    print(f"  {path}")
#
## Try manual import by adding to path
#import sys
#sys.path.insert(0, '/home/nicolas/miniforge3/lib/python3.12/site-packages')
#
#try:
#    import rich
#    print("✓ Rich imported after manual path adjustment")
#except ImportError as e:
#    print(f"✗ Still failed: {e}")

# %%
import os
# install the package if not yet installed
#try:
#    from branch.branch_x import Net
#except:
#    #!python -m pip install git+https://github.com/nguwijy/deep_branching_with_domain.git
#    from branch.branch_x import Net
import math
import time
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#import os
## Disable GPU for TensorFlow
#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
#
## Now set Keras backend
#os.environ['KERAS_BACKEND'] = 'tensorflow'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
from DeepBSDE2_HJB.main import main as deep_bsde

from branch.branch_x_single import Net
from branch.branch_cv_x import Net_cv
# Out:
# 2025-12-27 00:28:54.618335: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-27 00:28:55.013492: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-27 00:28:56.515174: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
def numerical_solution(xx_arr, T, dim, fixed_dim, problem_name, deriv_map, cstar, f_example, f_example_cv, phi_example, phi_example_cv, exact_example, exact_example_cv, nu):
    df = []
#    exact = exact_example(t=0, x=np.zeros((dim, 1)), T=0, coordinate=0)[0]
#    df.append([0, exact, exact, exact, exact, 0, 0, 0])
    for xx in xx_arr:
        x0 = np.eye(1, dim, fixed_dim)[0] * xx
#        x0 = np.full(dim,xx)
        x_single=x0
        print(f"Now dealing with x = {xx}...")
        # initialize branching model
        torch.manual_seed(0)
        model = Net(
            problem_name=problem_name,
            f_fun=f_example,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            x_single=x0,
            device=device,
            x_lo=xx,
            x_hi=xx,
            nu=nu,
            T=T,
            verbose=True,
            branch_nb_path_per_state=1000,
            branch_nb_states=1,
            branch_nb_states_per_batch=1,
            save_as_tmp=True,
        )
        print("Model complete")
        #model_cv = Net_cv(
        #    problem_name=problem_name,
        #    cstar=cstar,
        #    f_fun=f_example,
        #    f_fun_cv=f_example_cv,
        #    exact_fun_cv=exact_example_cv,
        #    deriv_map=deriv_map,
        #    phi_fun=phi_example,
        #    phi_fun_cv=phi_example_cv,
        #    device=device,
        #    x_lo=1.0,
        #    x_hi=1.0,
        #    nu=nu,
        #    T=T,
        #    verbose=True,
        #    branch_nb_path_per_state=1000,
        #    save_as_tmp=True,
        #)
        
        # tx = torch.zeros(1, model.dim_in + 1, device=device)
        tx = None
        
        # branching mc calculation
        start = time.time()
        mc, repeats = 0, 1
        for _ in range(repeats):
            x, y = model.gen_sample(patch=0, tx=tx)
            mc += y[:, 0].cpu()
            print("1000 samples")
        mc = mc[0].item() / repeats
        mc_time = time.time() - start

        start = time.time()
        mc_cv, repeats = 0, 10
        #for _ in range(repeats):
        #    x, y = model_cv.gen_sample_cv(patch=0, tx=tx)
        #    mc_cv += y[:, 0].cpu()
        #mc_cv = mc_cv[0].item() / repeats
        mc_cv_time = time.time() - start
        
        # exact calculation & bsde calculation
#        exact = exact_example(t=0, x=np.zeros((model.dim_in, 1)), T=T, coordinate=0)[0]
        exact = exact_example(t=0, x=x0, T=T, coordinate=0) # [0]
        start = time.time()
#        bsde = deep_bsde(total_time=T, verbose=False, nu=nu, num_iterations= 50, dim=dim, y_init_range=[0,1])[-1][2]
        bsde = deep_bsde(total_time=T, x_init=x0, verbose=False, nu=nu, num_iterations= 1000, dim=dim, y_init_range=[0,1.0])[-1][2]
        bsde_time = time.time() - start
        # exact = 0.61061
        df.append([xx,T, mc, mc_cv, bsde, exact, mc_time, mc_cv_time, bsde_time])
        ddf = pd.DataFrame(df, columns=['x', 'T', 'branch', 'branch_cv', 'deep_bsde', 'exact', 'branch time (seconds)', 'branch_cv time (seconds)', 'deep_bsde time (seconds)'])
        print(ddf)       
        
    # create df & save
    if not os.path.isdir('logs/'):
        os.makedirs('logs/')
    df = pd.DataFrame(df, columns=['x', 'T', 'branch', 'branch_cv', 'deep_bsde', 'exact', 'branch time (seconds)', 'branch_cv time (seconds)', 'deep_bsde time (seconds)'])
    df.to_csv("logs/" + problem_name + ".csv")
    
    return df

# %%
fixed_dim, dim = 0, 10
T = torch.tensor(0.1 , dtype=torch.float32)  # Time horizon
mu0 = 0.0
mu = 0.0 # mu0+0.1*dim

lbd = torch.tensor(1.0, dtype=torch.float32)  # Lambda parameter

t_lo, x_lo, x_hi = 0., 0., 0.
x_mid = (x_lo + x_hi) / 2
# x0 = x_mid * np.eye(1, dim) 
x0 = 1.0 * np.eye(1, dim) 

u1=0.
u2=1.

nu=2
lambd = (u1 + u2) / 2

def nth_derivatives(order, y, x):
    """
    Compute nth derivative of y with respect to x.
    """
    for _ in range(order):
        try:
            grads = torch.autograd.grad(y.sum(), x, create_graph=True)[0]
        except RuntimeError:
            # Handle zero gradient case gracefully
            return torch.zeros_like(y)
        y = grads
    return y

def u_cv(x, T):
    return u2+(u1-u2)/(1+torch.exp((u1-u2)*(mu0*x.sum(dim=0)-mu0**2*(u1+u2)*T*dim/2)/nu))                       

def u_cv_der(y, T):
    """
    First derivative of u_cv with respect to y.
    """
    return nth_derivatives(1, u_cv(y, T), y)

def f_cv0(y, T, mu):
    u_prime = u_cv_der(y, T)
    return (
        - mu * u_cv(y, T) * u_prime
    )
    
def phi(x,mu):
    """
    Example phi function.
    """
    return u2+(u1-u2)/(1+torch.exp((u1-u2)*(mu0*x.sum(dim=0))/nu))                       

def cov(x0, T, mu1, mu2): 
    """
    Compute covariance.
    """
    # Define the integrand for numerical integration
    def integrand(s):
        s_tensor = torch.tensor([s], dtype=torch.float32, requires_grad=True)
        x_tensor = torch.tensor(x0[0], dtype=torch.float32, requires_grad=True)
        # print(x_tensor)
        #print("f_cv0(x_tensor, s_tensor, mu1)=",f_cv0(x_tensor, s_tensor, mu1))
        #print(s_tensor)
        return f_cv0(x_tensor, s_tensor, mu1) * f_cv0(x_tensor, s_tensor, mu2) / lbd / torch.exp(-lbd * s_tensor )

    # Integrand for single function
    def integrand_single1(s):
        s_tensor = torch.tensor([s], dtype=torch.float32, requires_grad=True)
        x_tensor = torch.tensor(x0[0], dtype=torch.float32, requires_grad=True)
        return f_cv0(x_tensor, s_tensor, mu1)
    def integrand_single2(s):
        s_tensor = torch.tensor([s], dtype=torch.float32, requires_grad=True)
        x_tensor = torch.tensor(x0[0], dtype=torch.float32, requires_grad=True)
        return f_cv0(x_tensor, s_tensor, mu2)

    # Numerical integration (discretized)
    s = torch.linspace(0, T.item(), steps=100)
    #print([integrand(s_i)[0] for s_i in s])
    integrand_values = torch.stack([integrand(s_i)[0] for s_i in s])
    # print(integrand_values)
    integral = torch.trapezoid(integrand_values, s)
    #print(integral)
    integrand_values_single1 = torch.stack([integrand_single1(s_i)[0] for s_i in s])
    #print(integrand_values_single1)
    integral_single1 = torch.trapezoid(integrand_values_single1, s)
    #print(integral_single1)
    integrand_values_single2 = torch.stack([integrand_single2(s_i)[0] for s_i in s])
    #print(integrand_values_single2)
    integral_single2 = torch.trapezoid(integrand_values_single2, s)
    #print(integral_single2)
    x_tensor = torch.tensor(x0[0], dtype=torch.float32, requires_grad=True)
    return (
        phi(x_tensor,mu1)*phi(x_tensor,mu2) / torch.exp(-lbd * T)
        + integral - (phi(x_tensor,mu1) + integral_single1)*(phi(x_tensor,mu2) + integral_single2)
    )

# Execute the cov function
#print(cov(x0=x0, T=T, mu1=mu, mu2=mu0))
#print(cov(x0=x0, T=T, mu1=mu0, mu2=mu0))
cstar = - cov(x0=x0, T=T, mu1=mu, mu2=mu0)/cov(x0=x0, T=T, mu1=mu0, mu2=mu0)
cstar=cstar.item()
print("cstar:", cstar)
covar = cov(x0=x0, T=T, mu1=mu, mu2=mu0)
print("covar:", covar.item())
corr = cov(x0=x0, T=T, mu1=mu, mu2=mu0)/torch.sqrt(cov(x0=x0, T=T, mu1=mu, mu2=mu)*cov(x0=x0, T=T, mu1=mu0, mu2=mu0))
print("corr^2:", corr.item() ** 2)
if np.isnan(cstar): cstar=-1 
cstar=-1
# Out:
# cstar: -1.0
# covar: 0.02629271149635315
# corr^2: 1.0

# %%
# function definition
# deriv_map = np.array([0] * dim).reshape(-1, dim)
T=T.item()

gamma1=1.0; gamma2=0.1; gamma3=0.1;

# deriv_map = np.concatenate((np.array([[0] * dim]), 1 * np.identity(dim), 2 * np.identity(dim)), axis=0).astype(int)
# deriv_map = np.concatenate((1 * np.identity(dim), 2 * np.identity(dim)), axis=0).astype(int)
deriv_map = np.concatenate((np.array([[0] * dim]), 1 * np.identity(dim), 2 * np.identity(dim)), axis=0).astype(int)

def f_example(y, coordinate=0):
    """
    idx 0 -> no deriv
    """
    return (gamma2/2/dim*(y[0:dim]**2).sum(dim=0) 
            - mu * (y[0:dim]*y[dim:2*dim]).sum(dim=0) 
            - dim/2/gamma1 * (y[dim:2*dim]**2).sum(dim=0))
    # return gamma2*2/dim*y[0:dim]**2.sum(dim=0) - dim/2/gamma1 * y[dim] * y[dim:2*dim].sum(dim=0) 

def f_example_cv(y, coordinate=0):
    """
    idx 0 -> no deriv
    """
    return (gamma2/2/dim*(y[0:dim]**2).sum(dim=0) 
            - mu0 * (y[0:dim]*y[dim+1:2*dim+1]).sum(dim=0) 
            - dim/2/gamma1 * (y[dim+1:2*dim+1]**2).sum(dim=0))
    # return y[0:dim].sum(dim=0) - mu0 * y[dim] * y[dim:2*dim].sum(dim=0) 
    # return - mu0 * y[0] * y[1:(dim+1)].sum(dim=0) 

dgm_deriv_map = np.concatenate((deriv_map, 2 * np.identity(dim)), axis=0)

def dgm_f_example(y, coordinate=0):
    """
    idx 0      -> no deriv
    idx 1 to n -> second deriv
    """
    return gamma2*2/dim*(y[0:dim]**2).sum(dim=0) - dim/2/gamma1 * (y[dim+1:2*dim+1]**2).sum(dim=0) + nu * y[dim+1:2*dim+1].sum(dim=0) / 2
    # return - mu * y[0] * y[1:(dim+1)].sum(dim=0) + nu * y[(dim+1):(2*dim+1)].sum(dim=0) / 2 

def phi_example(x, coordinate=0):
    return gamma3/2/dim*(x[0:dim]**2).sum(dim=0)                       
#    return u2+(u1-u2)/(1+torch.exp((u1-u2)*mu*x.sum(dim=0)/nu))                       

def phi_example_cv(x, coordinate=0):
    return gamma3/2/dim*(x[0:dim]**2).sum(dim=0)                       
    # return u2+(u1-u2)/(1+torch.exp((u1-u2)*mu0*x.sum(dim=0)/nu))                       

# def phi_example(x, coordinate=0):
#    return -0.5 - 0.5 * torch.nn.Tanh()(-x[0] / 2)

# def exact_example(t, x, T):
#    return -0.5 - 0.5 * np.tanh(-x[0]/2 + 3*(T-t)/4)

lambdas=0.5*(np.sqrt(gamma2/gamma1)-gamma3/gamma1)

def exact_example(t, x, T, coordinate=0):
    sigmas2 = (1-np.exp(-2*np.sqrt(gamma2/gamma1)*(T-t)))/2/np.sqrt(gamma2/gamma1)
    return (np.sqrt(gamma1*gamma2)*(T-t)
            + gamma1*np.log(1 - 2 * sigmas2 * lambdas) 
            + (np.sqrt(gamma1*gamma2)+2*gamma1*lambdas*np.exp(-2*np.sqrt(gamma2/gamma1)*(T-t))
            / (2*lambdas*sigmas2-1))*(x**2).sum(axis=0)/2/dim)                       
    # return u2+(u1-u2)/(1+np.exp((u1-u2)*(mu*x.sum(axis=0)-mu**2*(u1+u2)*(T-t)*dim/2)/nu))                       

def exact_example_cv(t, x, T, coordinate=0):
    #print(x)
    t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
    x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
    T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
    sigmas2 = (1-torch.exp(-2*np.sqrt(gamma2/gamma1)*(T-t)))/2/np.sqrt(gamma2/gamma1)
    #print(t.size())
    #print("cv t=",t)
    #print(x.size())
    #print("cv x=",x)
    return (np.sqrt(gamma1*gamma2)*(T-t)
            + gamma1*torch.log(1 - 2 * sigmas2* lambdas) 
            + (np.sqrt(gamma1*gamma2)+2*gamma1*lambdas*torch.exp(-2*np.sqrt(gamma2/gamma1)*(T-t))
            / (2*lambdas*sigmas2-1))*(x**2).sum(dim=0)/2/dim)                          
    # return u2+(u1-u2)/(1+torch.exp((u1-u2)*(mu0*x.sum(dim=0)-mu0**2*(u1+u2)*(T-t)*dim/2)/nu))                       

def exact_example_cv_2(t, x, T, coordinate=0):
    sigmas2 = (1-np.exp(-2*np.sqrt(gamma2/gamma1)*(T-t)))/2/np.sqrt(gamma2/gamma1)
    return (np.sqrt(gamma1*gamma2)*(T-t)
            + gamma1*np.log(1 - 2 * sigmas2* lambdas) 
            + (np.sqrt(gamma1*gamma2)+2*gamma1*lambdas*np.exp(-2*np.sqrt(gamma2/gamma1)*(T-t))
            / (2*lambdas*sigmas2-1))*(x**2).sum(axis=0)/2/dim)                          
    # return u2+(u1-u2)/(1+np.exp((u1-u2)*(mu0*x.sum(axis=0)-mu0**2*(u1+u2)*(T-t)*dim/2)/nu))                       

grid = np.linspace(x_lo, x_hi, 100)
x_mid = (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

true = exact_example(t_lo, grid_d_dim, T)
terminal = exact_example(T, grid_d_dim, T)
true_nn = exact_example_cv_2(0, grid_d_dim, T)

# %%
problem_name = f"allen_cahn_jeeq_dim_{dim}_blow_up_analysis"

T=0.1
x_low=-2; x_high=2.0
delta_x = (x_high-x_low)/10
xx_arr = np.arange(x_low, x_high, delta_x)
df = numerical_solution(
    T=T,
    xx_arr=xx_arr,
    dim=dim,
    fixed_dim=1,
    problem_name=problem_name,
    deriv_map=deriv_map,
    cstar=cstar,
    f_example=f_example,
    f_example_cv=f_example_cv, 
    phi_example=phi_example,
    phi_example_cv=phi_example_cv,
    exact_example=exact_example,
    exact_example_cv=exact_example_cv,
    nu=nu
)
# Out:
# Now dealing with x = -2.0...
# Logs are saved in /home/nicolas/NTU/laurent_mertz/coding_trees/logs/tmp
# Deep BSDE Begin to solve HJBMultidim
# Model complete
# 1000 samples
# 2025-12-27 00:29:19.774115: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.776564: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.778439: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.780169: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.781930: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.783730: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.785547: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.787353: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.789146: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.790976: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.793157: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.794979: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.796851: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.798728: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.800615: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.802493: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.804433: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.806391: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:19.808337: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.864484: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.877399: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.877755: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.878097: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.878440: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.878789: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.879135: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.879480: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.879829: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.880174: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.880515: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.880862: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.881208: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.881553: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.881906: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.882252: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.882608: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.882951: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:20.883294: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# Y0_true: 3.1962e-02
# relative error of Y0: 7.03%
#      x    T    branch  branch_cv  deep_bsde     exact  branch time (seconds)  \
# 0 -2.0  0.1  0.031993          0   0.029716  0.032229               0.119226
#
#    branch_cv time (seconds)  deep_bsde time (seconds)
# 0              4.768372e-07                  28.75773
# Now dealing with x = -1.6...
# Logs are saved in /home/nicolas/NTU/laurent_mertz/coding_trees/logs/tmp
# Deep BSDE Begin to solve HJBMultidim
# Model complete
# 1000 samples
# 2025-12-27 00:29:52.333186: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.336245: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.338010: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.339848: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.341701: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.343525: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.345387: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.347275: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.349176: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.351101: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.353049: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.355016: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.356954: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.358915: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.360905: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.362876: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.364856: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.366848: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:52.368837: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.427971: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.441183: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.441562: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.441936: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.442294: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.442679: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.443038: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.443403: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.443772: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.444138: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.444504: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.444875: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.445253: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.445621: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.445985: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.446358: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.446736: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.447111: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-27 00:29:53.447485: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# Y0_true: 2.4198e-02
# relative error of Y0: 1412.09%
#      x    T    branch  branch_cv  deep_bsde     exact  branch time (seconds)  \
# 0 -2.0  0.1  0.031993          0   0.029716  0.032229               0.119226
# 1 -1.6  0.1  0.024350          0   0.365893  0.024387               0.121700
#
#    branch_cv time (seconds)  deep_bsde time (seconds)
# 0              4.768372e-07                 28.757730
# 1              4.768372e-07                 29.840173
# Now dealing with x = -1.2000000000000002...
# Logs are saved in /home/nicolas/NTU/laurent_mertz/coding_trees/logs/tmp
# Deep BSDE Begin to solve HJBMultidim
# Model complete
# 1000 samples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       5 delta_x = (x_high-x_low)/10
#       6 xx_arr = np.arange(x_low, x_high, delta_x)
# ----> 7 df = numerical_solution(
#       8     T=T,
#       9     xx_arr=xx_arr,
#      10     dim=dim,
#      11     fixed_dim=1,
#      12     problem_name=problem_name,
#      13     deriv_map=deriv_map,
#      14     cstar=cstar,
#      15     f_example=f_example,
#      16     f_example_cv=f_example_cv,
#      17     phi_example=phi_example,
#      18     phi_example_cv=phi_example_cv,
#      19     exact_example=exact_example,
#      20     exact_example_cv=exact_example_cv,
#      21     nu=nu
#      22 )
#
# Cell In[3], line 75, in numerical_solution(xx_arr, T, dim, fixed_dim, problem_name, deriv_map, cstar, f_example, f_example_cv, phi_example, phi_example_cv, exact_example, exact_example_cv, nu)
#      73         start = time.time()
#      74 #        bsde = deep_bsde(total_time=T, verbose=False, nu=nu, num_iterations= 50, dim=dim, y_init_range=[0,1])[-1][2]
# ---> 75         bsde = deep_bsde(total_time=T, x_init=x0, verbose=False, nu=nu, num_iterations= 1000, dim=dim, y_init_range=[0,1.0])[-1][2]
#      76         bsde_time = time.time() - start
#      77         # exact = 0.61061
#
# File ~/NTU/laurent_mertz/coding_trees/DeepBSDE2_HJB/main.py:81, in main(total_time, x_init, dim, nu, num_time_interval, y_init_range, num_hiddens, lr_values, lr_boundaries, num_iterations, batch_size, valid_size, logging_frequency, dtype, verbose)
#      79 logging.info('Deep BSDE Begin to solve %s ' % eqn_config.eqn_name)
#      80 bsde_solver = BSDESolver(config, bsde)
# ---> 81 training_history = bsde_solver.train()
#      82 if bsde.y_exact:
#      83     logging.info('Y0_true: %.4e' % bsde.y_exact)
#
# File ~/NTU/laurent_mertz/coding_trees/DeepBSDE2_HJB/solver.py:36, in BSDESolver.train(self)
#      33         if self.net_config.verbose:
#      34             logging.info("step: %5u,    loss: %.4e, Y0: %.4e,   elapsed time: %3u" % (
#      35                 step, loss, y_init, elapsed_time))
# ---> 36     self.train_step(self.bsde.sample(self.net_config.batch_size))
#      37 return np.array(training_history)
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:988, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     985 else:
#     986   deps_control_manager = ops.NullContextmanager()
# --> 988 with func_graph.as_default(), deps_control_manager as deps_ctx:
#     989   current_scope = variable_scope.get_variable_scope()
#     990   default_use_resource = current_scope.use_resource
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:459, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     456 resource_inputs = set()
#     457 # Check for any resource inputs. If we find any, we update control_inputs
#     458 # and last_write_to_resource.
# --> 459 for inp, resource_type in _get_resource_inputs(op):
#     460   is_read = resource_type == ResourceType.READ_ONLY
#     461   input_id = ops.tensor_id(inp)
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:608, in _get_resource_inputs(op)
#     606 def _get_resource_inputs(op):
#     607   """Returns an iterable of resources touched by this `op`."""
# --> 608   reads, writes = utils.get_read_write_resource_inputs(op)
#     609   saturated = False
#     610   while not saturated:
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps_utils.py:96, in get_read_write_resource_inputs(op)
#      85 def get_read_write_resource_inputs(op):
#      86   """Returns a tuple of resource reads, writes in op.inputs.
#      87
#      88   Args:
#    (...)     94     `op.inputs`.
#      95   """
# ---> 96   reads = object_identity.ObjectIdentitySet()
#      97   writes = object_identity.ObjectIdentitySet()
#      99   if op.type in RESOURCE_READ_OPS:
#     100     # Add all resource inputs to `reads` and return.
#
# File ~/miniforge3/lib/python3.12/site-packages/tensorflow/python/util/object_identity.py:182, in ObjectIdentitySet.__init__(self, *args)
#     178 """Like the built-in set, but compares objects with "is"."""
#     180 __slots__ = ["_storage", "__weakref__"]
# --> 182 def __init__(self, *args):
#     183   self._storage = set(self._wrap_key(obj) for obj in list(*args))
#     185 def __le__(self, other: Set[Any]) -> bool:
#
# KeyboardInterrupt:

# %%
print(df)
# df.plot(x='T', y=['branch', 'branch_cv', 'deep_bsde', 'exact'])
df.plot(x='x', y=['branch', 'branch_cv', 'deep_bsde', 'exact'],color=['orange', 'blue', 'purple', 'black'],label=["Deep branching","Deep branching CV","Deep BSDE","Exact"]).grid(True)
# Out:
#               x    T    branch  branch_cv  deep_bsde     exact  \
# 0 -2.000000e+00  0.1  0.204484          0   0.224160  0.228263
# 1 -1.600000e+00  0.1  0.139614          0   0.158323  0.149849
# 2 -1.200000e+00  0.1  0.085292          0   0.384162  0.088861
# 3 -8.000000e-01  0.1  0.044431          0   0.049352  0.045297
# 4 -4.000000e-01  0.1  0.019099          0   0.039033  0.019160
# 5 -4.440892e-16  0.1  0.010512          0   0.009416  0.010447
# 6  4.000000e-01  0.1  0.019038          0   0.058124  0.019160
# 7  8.000000e-01  0.1  0.044198          0   0.060149  0.045297
# 8  1.200000e+00  0.1  0.084663          0   0.346780  0.088861
# 9  1.600000e+00  0.1  0.138253          0   0.145519  0.149849
#
#    branch time (seconds)  branch_cv time (seconds)  deep_bsde time (seconds)
# 0               0.128895              9.536743e-07                 36.033161
# 1               0.126497              2.384186e-07                 31.099596
# 2               0.150497              7.152557e-07                 33.672360
# 3               0.116229              2.384186e-07                 30.394216
# 4               0.116073              7.152557e-07                 33.132285
# 5               0.109037              4.768372e-07                 30.625191
# 6               0.110647              2.384186e-07                 33.631092
# 7               0.120755              4.768372e-07                 30.051653
# 8               0.115592              2.384186e-07                 30.275992
# 9               0.119671              2.384186e-07                 30.188110

# %%
import matplotlib.pyplot as plt

# Create a figure and axes
fig, ax = plt.subplots()

# Plot each series with custom settings
ax.plot(df['T'], df['exact'], color='black', label='Exact')
ax.plot(df['T'], df['branch'], color='orange', label='Deep branching')
ax.plot(df['T'], df['branch_cv'], 
        linestyle='None', marker='o', markersize=4,
        markerfacecolor='none', markeredgecolor='blue',
        label='Deep branching CV')
ax.plot(df['T'], df['deep_bsde'], color='purple', label='Deep BSDE')
plt.xlabel("T")
# plt.ylim(0.499975, 0.50025)
plt.margins(x=0)
# Add grid and legend
ax.grid(True)
ax.legend()

# %%
xx_arr
# Out:
# array([-2.0000000e+00, -1.6000000e+00, -1.2000000e+00, -8.0000000e-01,
#        -4.0000000e-01, -4.4408921e-16,  4.0000000e-01,  8.0000000e-01,
#         1.2000000e+00,  1.6000000e+00])

# %%
T=1
grid_1d = np.linspace(0,T,100) 
x_mid = 0.0 # (x_lo + x_hi) / 2
grid_d_dim = np.concatenate((x_mid * np.ones((fixed_dim, 100)), np.expand_dims(grid_1d, axis=0), x_mid * np.ones((dim - fixed_dim - 1, 100))), axis=0)
# grid_d_dim_with_t = np.concatenate((t_lo * np.ones((1, 100)), grid_d_dim), axis=0)

true_nn = exact_example_cv(0, x_mid * np.ones((fixed_dim, 100)), grid_1d)
exact = exact_example(0, x_mid * np.ones((fixed_dim, 100)), grid_1d)
terminal = exact_example_cv_2(T, grid_d_dim, T,0)

f = plt.figure()
# plt.plot(grid_1d, true, label="True solution")
plt.plot(grid_1d, exact, color='black', label="Exact solution")
plt.plot(grid_1d, true_nn, color='orange', label="Control variate solution")
plt.xlabel("T")
# plt.plot(grid_1d, terminal, color='green', label="Terminal condition")
# plt.ylim(0.499975, 0.50025)
plt.margins(x=0)
plt.grid(True)
plt.legend()
plt.show()

# %%
exact_example(0, torch.tensor([3.0]), 0.1,coordinate=0)
