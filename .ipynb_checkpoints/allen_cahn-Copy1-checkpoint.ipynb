# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/nguwijy/coding_trees/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # suppress INFO and WARNING
import gc
# install the package if not yet installed
#try:
#    from branch.branch import Net
#except:
#    !python -m pip install git+https://github.com/nguwijy/deep_branching_with_domain.git
#    from branch.branch import Net
import math
import time

import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("torch.cuda.is_available=",torch.cuda.is_available())
if torch.cuda.device_count() > 1:
    device0 = torch.device("cuda:0")
    device1 = torch.device("cuda:1")
else:
    device0 = device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.set_default_dtype(torch.float64)

from DeepBSDE2.main import main as deep_bsde

from branch.branch_v2 import Net
from branch.branch_NPP23 import Net_NPP23

# from branch.branch_cv import Net_cv
# Out:
# torch.cuda.is_available= True
# 2026-02-27 16:26:30.406632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772180790.466949 1480119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772180790.482740 1480119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772180790.618026 1480119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772180790.618059 1480119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772180790.618060 1480119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772180790.618062 1480119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow is using: NVIDIA RTX A4000 (GPU 0)

# %% [markdown]
# ## Allen Cahn Equation

# %%
def blow_up_analysis(T_arr, 
                     fixed_dim,
                     dim, 
                     branch_nb_path_per_state, 
                     branch_nb_states_per_batch, 
                     branch_nb_states,
                     outlier_percentile,
                     repeats,
                     num_iterations,
                     y_init_range,
                     nu, 
                     xlo, 
                     xhi):

    problem_name = f"allen_cahn_dim_{dim}_time_behavior"

    deriv_map = np.array([0] * dim).reshape(-1, dim)

    mu=1
    def f_example2(y):
        """
        idx 0 -> no deriv
        """
        return mu * ( y - y ** 3 ) 

    def f_example(y):
        """
        idx 0 -> no deriv
        """
        return mu * ( y[0] - y[0] ** 3 )

    def f_example_NPP23(y, coordinate=0):
        """
        idx 0 -> no deriv
        """
        return mu * ( y[0] - y[0] ** 3 )

    def phi_example(x, coordinate=0):
        scale = torch.sqrt(torch.tensor(x.shape[0], dtype=x.dtype, device=x.device))
        z = x.sum(dim=0) / scale
        z = -0.5 * z
        return -0.5 - 0.5 * torch.tanh(z)

    def phi_example_NPP23(x, coordinate=0):
        return (-0.5 - 0.5 * torch.nn.Tanh()(-.5 * x.sum(dim=0) / math.sqrt(dim)))

    def exact_example(t, x, T, coordinate=0):
        t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
        x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
        T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
        return -0.5 - 0.5 * torch.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

    def exact_example_NPP23(t, x, T, coordinate=0):
        t = torch.tensor(t, dtype=torch.float32) if not isinstance(t, torch.Tensor) else t
        x = torch.tensor(x, dtype=torch.float32) if not isinstance(x, torch.Tensor) else x
        T = torch.tensor(T, dtype=torch.float32) if not isinstance(T, torch.Tensor) else T
        return -0.5 - 0.5 * torch.tanh(-.5*x.sum(axis=0)/math.sqrt(dim) + 3*(T-t)/4)

    df = []
    for T in T_arr:
#        print(f"Now dealing with T = {T}...")
        # initialize branching model
        torch.manual_seed(0)
        model = Net(
            problem_name=problem_name,
            f_fun2=f_example2,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            device=device1,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
             save_as_tmp=True,
        ).to(device1)

        model_NPP23 = Net_NPP23(
            problem_name=problem_name,
            f_fun=f_example_NPP23,
#            f_fun_NPP23=f_example_NPP23,
            exact_fun_NPP23=exact_example_NPP23,
            deriv_map=deriv_map,
            phi_fun=phi_example,
            phi_fun_NPP23=phi_example_NPP23,
            device=device0,
            x_lo=xlo,
            x_hi=xhi,
            nu=nu,
            T=T,
            outlier_percentile=outlier_percentile,
            verbose=True,
            branch_nb_path_per_state=branch_nb_path_per_state,
            branch_nb_states_per_batch=branch_nb_states_per_batch,
            branch_nb_states=branch_nb_states, 
            save_as_tmp=True,
        ).to(device0)
        
        tx = torch.zeros(1, dim + 1, device=device1)
        tx[:, -1] = torch.linspace(model.x_lo, model.x_hi, 1)
        
        # branching mc calculation
        start = time.time()
        mc = 0
        for _ in range(repeats):
            x, y = model.gen_sample(patch=0, tx=tx)
            mc += y[:, 0].cpu()
        mc = mc[0].item() / repeats
        mc_time = time.time() - start

        tx=tx.to(device0)
        start = time.time()
        mc_NPP23 = 0
        for _ in range(repeats):
            x, y = model_NPP23.gen_sample(patch=0, tx=tx)
            mc_NPP23 += y[:, 0].cpu()
        mc_NPP23 = mc_NPP23[0].item() / repeats
        mc_NPP23_time = time.time() - start
        
        xz = tx[:, 1:].T.unsqueeze(-1).repeat((1, 1, 1))
        exact = exact_example(t=0, x=xz.cpu(), T=T, coordinate=0)[0].cpu().item()
        start = time.time()
        bsde = deep_bsde(total_time=T, verbose=False, nu=nu, dim=dim, num_iterations=num_iterations, y_init_range=y_init_range)[-1][2]
        bsde_time = time.time() - start
        # exact = 0.61061
        df.append([format(T, ".2f"), format(mc, ".5f"), format(mc_NPP23,".5f"), format(bsde,".5f"), format(exact,".5f"), format(mc_time,".2f"), format(mc_NPP23_time,".2f"), format(bsde_time,".2f")])
        print(problem_name)
        print("dim=",dim)
        print(pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time']))

        del model              # remove model object
        del model_NPP23
        gc.collect()           # free Python objects
        torch.cuda.empty_cache()  # release cached GPU memory
    
    # create df & save
    if not os.path.isdir('logs/'):
        os.makedirs('logs/')
    df = pd.DataFrame(df, columns=['T', 'branch', 'NPP23', 'bsde', 'exact', 'br-time', 'NPP time', 'bsde time'])
    df.to_csv("logs/" + problem_name + ".csv")

    grid_1d = np.linspace(0,T,100) 
    x_mid = (xlo + xhi) / 2
    exact = exact_example(0, x_mid * np.ones((fixed_dim, 100)), grid_1d)

    fig, ax = plt.subplots()
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='-', color='red', label='Binary')
    ax.plot(df['T'].astype(float), df['NPP23'].astype(float), color='blue', label='NPP23')
    ax.plot(df['T'].astype(float), df['exact'].astype(float), color='black', label='Exact',linestyle='--')
    ax.plot(df['T'].astype(float), df['bsde'].astype(float), color='purple', label='BSDE')
    ax.plot(df['T'].astype(float), df['branch'].astype(float), linestyle='None', marker='o', color='red', markerfacecolor='none')
    ax.set_xlabel("T")
    ax.margins(x=0)
    ax.legend(loc="upper right")
    plt.tight_layout()
    ax.grid(True)
    fig.savefig("logs/" + problem_name + ".pdf", bbox_inches="tight")
    # Save df to LaTeX
    df = df.astype(str)
    latex_str = df.to_latex(
        index=False,             
    #    float_format="%.5f",      
        column_format="c"*len(df.columns),  
        caption=None,             
        label=None,               
        bold_rows=False
    )
    with open("logs/" + problem_name + "table.tex", "w") as f:
        f.write(latex_str)    
        
    return df

# %%
T=0.5
delta_t = 0.05
T_arr = np.arange(delta_t, T + delta_t, delta_t)
branch_nb_path_per_state=10000
branch_nb_states_per_batch=10
branch_nb_states=1000
outlier_percentile=5
repeats=100
num_iterations=4000
y_init_range=[-1,0]
xlo=0.0
xhi=0.0
nu=1.0

# %% [markdown]
# ### Dimension d = 1

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
# Out:
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# 1  0.10  -0.53710  -0.53745  -0.50000  -0.53743    0.22     0.17      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# 1  0.10  -0.53710  -0.53745  -0.50000  -0.53743    0.22     0.17      0.00
# 2  0.15  -0.55550  -0.55619  -0.50000  -0.55601    0.22     0.20      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# 1  0.10  -0.53710  -0.53745  -0.50000  -0.53743    0.22     0.17      0.00
# 2  0.15  -0.55550  -0.55619  -0.50000  -0.55601    0.22     0.20      0.00
# 3  0.20  -0.57371  -0.57487  -0.50000  -0.57444    0.21     0.19      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# 1  0.10  -0.53710  -0.53745  -0.50000  -0.53743    0.22     0.17      0.00
# 2  0.15  -0.55550  -0.55619  -0.50000  -0.55601    0.22     0.20      0.00
# 3  0.20  -0.57371  -0.57487  -0.50000  -0.57444    0.21     0.19      0.00
# 4  0.25  -0.59174  -0.59349  -0.50000  -0.59267    0.21     0.20      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51851  -0.51868  -0.50000  -0.51874    0.48     0.19      0.00
# 1  0.10  -0.53710  -0.53745  -0.50000  -0.53743    0.22     0.17      0.00
# 2  0.15  -0.55550  -0.55619  -0.50000  -0.55601    0.22     0.20      0.00
# 3  0.20  -0.57371  -0.57487  -0.50000  -0.57444    0.21     0.19      0.00
# 4  0.25  -0.59174  -0.59349  -0.50000  -0.59267    0.21     0.20      0.00
# 5  0.30  -0.60961  -0.61203  -0.50000  -0.61064    0.21     0.19      0.00
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_1_time_behavior
# dim= 1
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# allen_cahn_dim_100_time_behavior
# dim= 100
#       T    branch     NPP23      bsde     exact br-time NPP time bsde time
# 0  0.05  -0.51890  -0.51865  -0.50000  -0.51874    1.86     1.49      0.00
# 1  0.10  -0.53727  -0.53749  -0.50000  -0.53743    1.87     1.45      0.00
# 2  0.15  -0.55556  -0.55679  -0.50000  -0.55601    1.88     1.43      0.00
# 3  0.20  -0.57372  -0.57668  -0.50000  -0.57444    1.89     1.44      0.00
# 4  0.25  -0.59174  -0.59136  -0.50000  -0.59267    1.93     1.39      0.00
# 5  0.30  -0.60959  -0.60923  -0.50000  -0.61064    1.89     1.42      0.00
# 6  0.35  -0.62059  -0.62699  -0.50000  -0.62832    1.94     1.29      0.00
# 7  0.40  -0.63608  -0.64463  -0.50000  -0.64566    1.87     1.40      0.00
# 8  0.45  -0.65112  -0.66218  -0.50000  -0.66262    1.87     1.42      0.00
# 9  0.50  -0.66571  -0.67962  -0.50000  -0.67918    1.90     1.42      0.00

# %%
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ### Dimension d = 300

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=300,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
# Out:
# Logs are saved in /home/nprivault/NTU/huang_qiao/PDEs/coding_trees/logs/tmp
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = blow_up_analysis(
#       2     T_arr=T_arr,
#       3     fixed_dim=0,
#       4     dim=300,
#       5     branch_nb_path_per_state=branch_nb_path_per_state,
#       6     branch_nb_states_per_batch=branch_nb_states_per_batch,
#       7     branch_nb_states=branch_nb_states,
#       8     outlier_percentile=outlier_percentile,
#       9     repeats=repeats,
#      10     nu=nu,
#      11     num_iterations=num_iterations,
#      12     y_init_range=y_init_range,
#      13     xlo=xlo,
#      14     xhi=xhi
#      15 )
#
# Cell In[2], line 110, in blow_up_analysis(T_arr, fixed_dim, dim, branch_nb_path_per_state, branch_nb_states_per_batch, branch_nb_states, outlier_percentile, repeats, num_iterations, y_init_range, nu, xlo, xhi)
#     108 mc = 0
#     109 for _ in range(repeats):
# --> 110     x, y = model.gen_sample(patch=0, tx=tx)
#     111     mc += y[:, 0].cpu()
#     112 mc = mc[0].item() / repeats
#
# File ~/NTU/huang_qiao/PDEs/coding_trees/branch/branch_v2.py:2026, in Net.gen_sample(self, patch, tx)
#    2017 unif = (
#    2018     torch.rand(states_per_batch, device=self.device)
#    2019     .repeat(self.nb_path_per_state)
#    2020     .reshape(self.nb_path_per_state, -1)
#    2021     .T
#    2022 )
#    2023 t = t_lo + (t_hi - t_lo) * unif
#    2024 unif = (
#    2025     torch.rand(self.dim_in * states_per_batch, device=self.device)
# -> 2026     .repeat(self.nb_path_per_state)
#    2027     .reshape(self.nb_path_per_state, -1)
#    2028     .T.reshape(self.dim_in, states_per_batch, self.nb_path_per_state)
#    2029 )
#    2030 if tx is None:
#    2031     x = x_lo + (x_hi - x_lo) * unif
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 22.35 GiB. GPU 0 has a total capacity of 15.61 GiB of which 13.41 GiB is free. Including non-PyTorch memory, this process has 420.00 MiB memory in use. Of the allocated memory 155.92 MiB is allocated by PyTorch, and 80.08 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ### Dimension d = 500

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=500,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)

# %% [markdown]
# ### Dimension d = 1000

# %%
df = blow_up_analysis(
    T_arr=T_arr,
    fixed_dim=0,
    dim=1000,
    branch_nb_path_per_state=branch_nb_path_per_state, 
    branch_nb_states_per_batch=branch_nb_states_per_batch,
    branch_nb_states=branch_nb_states,
    outlier_percentile=outlier_percentile,
    repeats=repeats,
    nu=nu,
    num_iterations=num_iterations,
    y_init_range=y_init_range,
    xlo=xlo,
    xhi=xhi
)
